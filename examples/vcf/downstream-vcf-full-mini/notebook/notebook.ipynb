# %% [markdown]
# # Downstream VCF Mini Notebook\n\nOptional notebook for plotting artifacts generated by the CLI runner.

# %%
import json\nfrom pathlib import Path\n\nart = Path('artifacts/examples/vcf_downstream_vcf_full_mini')\nreport = json.loads((art / 'report.json').read_text())\nreport
